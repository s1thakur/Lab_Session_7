# %%
import pandas
import pandas_datareader
import datetime
df = pandas.read_excel("lab2.2.xlsx")
df.head()
# Out:
#                         Entity  Year Records_Lost Organization  \
# 1                          AOL  2004      $92.0MM          web
# 2    Automatic Data Processing  2005     $0.125MM    financial
# 3              Ameritrade Inc.  2005       $0.2MM    financial
# 4                    Citigroup  2005       $3.9MM    financial
# 5  Cardsystems Solutions Inc.   2005      $40.0MM    financial
#
#          Method Of Leak  Data Sensitivity
# 1            inside job                 1
# 2         poor security                20
# 3  lost / stolen device                20
# 4  lost / stolen device               300
# 5                hacked               300

# %%
# !pip install pandas-datareader
# Out:
# ...
#   Running setup.py bdist_wheel for requests-ftp: started
#   Running setup.py bdist_wheel for requests-ftp: finished with status 'done'
#   Stored in directory: C:\Users\Sanjana Thakur\AppData\Local\pip\Cache\wheels\76\fb\0d\1026eb562c34a4982dc9d39c9c582a734eefe7f0455f711deb
#   Running setup.py bdist_wheel for requests-file: started
#   Running setup.py bdist_wheel for requests-file: finished with status 'done'
#   Stored in directory: C:\Users\Sanjana Thakur\AppData\Local\pip\Cache\wheels\3e\34\3a\c2e634ca7b545510c1b3b7d94dea084e5fdb5f33558f3c3a81
# Successfully built requests-ftp requests-file
# ...

# %%
# !pip install git+https://github.com/pydata/pandas-datareader.git
# Out:
# ...
#   Cloning https://github.com/pydata/pandas-datareader.git to c:\users\sanjan~1\appdata\local\temp\pip-4n8zugzs-build
# ...

# %%
import pandas_datareader as pdr
pdr.get_data_yahoo('AAPL').head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2010-01-04  30.490000  30.642857  30.340000  30.572857  27.505054  123432400
# 2010-01-05  30.657143  30.798571  30.464285  30.625713  27.552608  150476200
# 2010-01-06  30.625713  30.747143  30.107143  30.138571  27.114347  138040000
# 2010-01-07  30.250000  30.285715  29.864286  30.082857  27.064222  119282800
# 2010-01-08  30.042856  30.285715  29.865715  30.282858  27.244156  111902700

# %%
# !pip install fuzzywuzzy

# %%
# !pip install fuzzywuzzy[speedup]
# Out:
# ...
#   Using cached python-Levenshtein-0.12.0.tar.gz
# ...
#   Running setup.py bdist_wheel for python-levenshtein: started
#   Running setup.py bdist_wheel for python-levenshtein: finished with status 'error'
#   Complete output from command C:\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\SANJAN~1\\AppData\\Local\\Temp\\pip-build-zzo2cjdu\\python-levenshtein\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\SANJAN~1\AppData\Local\Temp\tmpqez46q6tpip-wheel- --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.6
#   creating build\lib.win-amd64-3.6\Levenshtein
#   copying Levenshtein\StringMatcher.py -> build\lib.win-amd64-3.6\Levenshtein
#   copying Levenshtein\__init__.py -> build\lib.win-amd64-3.6\Levenshtein
#   running egg_info
# ...

# %%
# !pip install git+git://github.com/seatgeek/fuzzywuzzy.git@0.15.1#egg=fuzzywuzzy

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
import json
import requests

def get_ticker(name):
    link = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(name)
    result = requests.get(link).json()    
    for x in result['ResultSet']['Result']:
                    return x['symbol']
      
ticker=[]
cname = df.Entity

for  xyz in cname:
    ticker.append(get_ticker(xyz))

print(ticker)
# Out:
# ['AOL-U.TI', 'ADP', None, 'CIT-U.TI', None, 'HPQ', None, 'KDDIY', None, 'AOL-U.TI', None, None, None, 'GPS', None, None, None, None, None, 'AMTD', 'FIS', 'DNPCF', None, None, None, None, None, 'AT', 'SBUX', None, None, None, '^UMIAMIFL', None, None, None, None, None, None, None, None, None, None, None, None, 'LYNS', None, None, 'IGRW', None, None, None, None, 'HTLD', None, 'AT', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'PPB.L', 'JPM-PB', None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'CIT-U.TI', None, None, 'GB00B1Z54R10.L', None, None, None, 'MBSS.JK', None, None, None, None, None, None, None, 'NHS', None, None, None, '600488.SS', '200771.SZ', None, None, None, None, None, None, None, None, None, 'GPN', None, None, None, None, None, 'KTC.DU', None, 'AAPL', 'ATVI', None, None, None, None, 'KCT.V', 'K55306BA2822.KS', None, None, None, None, None, None, 'CIT-U.TI', None, None, '2GF.F', 'NTDOY', 'TWTR'
# ...

# %%
start = datetime.datetime(2005,1,1)
end = datetime.datetime(2017,6,6)
data_source = 'yahoo'
PanelData = pandas_datareader.DataReader(ticker, data_source, start, end)
# Out:
# C:\Anaconda3\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: 'AOL-U.TI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Anaconda3\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: 'ADP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Anaconda3\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: None, replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Anaconda3\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: 'CIT-U.TI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Anaconda3\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: 'HPQ', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
c = PanelData.ix['Close']
weekdays = pandas.date_range(start=start, end=end, freq='B')
c = c.reindex(weekdays)
c.head()
# Out:
#                   ADP       HPQ  KDDIY        GPS   AMTD        FIS  DNPCF  \
# 2005-01-03  34.775860  9.559491    NaN  20.969999  14.01  35.240002    NaN
# 2005-01-04  34.220715  9.495913    NaN  20.650000  13.27  34.950001    NaN
# 2005-01-05  34.077965  9.536785    NaN  20.740000  13.07  34.799999    NaN
# 2005-01-06  33.847977  9.518620    NaN  20.950001  13.09  35.040001    NaN
# 2005-01-07  33.784531  9.464124    NaN  20.719999  13.16  35.110001    NaN
#
#             AT     SBUX  LYNS   ...     AOL-U.TI  NaN  CIT-U.TI  ^UMIAMIFL  \
# 2005-01-03 NaN  15.2850   NaN   ...          NaN  NaN       NaN        NaN
# 2005-01-04 NaN  15.2750   NaN   ...          NaN  NaN       NaN        NaN
# 2005-01-05 NaN  15.4000   NaN   ...          NaN  NaN       NaN        NaN
# 2005-01-06 NaN  14.9350   NaN   ...          NaN  NaN       NaN        NaN
# 2005-01-07 NaN  14.9175   NaN   ...          NaN  NaN       NaN        NaN
#
#             JPM-PB  KCT.V  NMBS.KL  CPWFF8.EX  FLINGX  1880.HK
# ...

# %%
c.to_csv('C:/Users/Sanjana Thakur/Desktop/MSIS/Dashboards/lab3.csv')

# %%
data_ticker = pandas.DataFrame(ticker) 
data_ticker['Ticker_Symbol'] = pandas.Series(ticker, index=data_ticker.index)
df['Ticker_symbol']= data_ticker['Ticker_Symbol']
df = df.dropna(axis=0,how='any')
df.head()
# Out:
#                         Entity  Year Records_Lost Organization  \
# 1                          AOL  2004      $92.0MM          web
# 3              Ameritrade Inc.  2005       $0.2MM    financial
# 5  Cardsystems Solutions Inc.   2005      $40.0MM    financial
# 7   Countrywide Financial Corp  2006       $2.6MM    financial
# 9   T-Mobile, Deutsche Telecom  2006      $17.0MM     telecoms
#
#          Method Of Leak  Data Sensitivity Ticker_symbol
# 1            inside job                 1           ADP
# 3  lost / stolen device                20      CIT-U.TI
# 5                hacked               300           HPQ
# 7            inside job               300         KDDIY
# 9  lost / stolen device                 1      AOL-U.TI

# %%
df.to_csv('C:/Users/Sanjana Thakur/Desktop/MSIS/Dashboards/Lab3.2.csv')
